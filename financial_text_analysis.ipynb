# %% [markdown]
# ## finacial analysis text-classification

# %%
import transformers
from transformers import pipeline

# %%
# Use a pipeline as a high-level helper
pipe = pipeline("text-classification", model="ProsusAI/finbert")
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Device set to use cpu

# %%
pipe("shares of Amazon are falling even though they beat earnings expections")
# Out:
# [{'label': 'negative', 'score': 0.9726600050926208}]

# %% [markdown]
# pass in a list of objects

# %%
tweets = ['earnings are not goood', 'this company beat the expected EPS']

# %%
pipe(tweets)
# Out:
# [{'label': 'neutral', 'score': 0.915668249130249},
#  {'label': 'positive', 'score': 0.9361554384231567}]

# %%
type(pipe)
# Out:
# transformers.pipelines.text_classification.TextClassificationPipeline
